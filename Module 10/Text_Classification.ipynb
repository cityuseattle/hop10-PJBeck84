# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
#load data
data = keras.datasets.imdb

#load the 10000 most frequently used throughout the whole dataset.
(train_data, train_labels), (test_data, test_labels) = data.load_data(num_words=10000)

# %%
#display data
print(train_data[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
#map the words
word_index = data.get_word_index()

# %%
word_index = {word:(num+3) for word,num in word_index.items()}
word_index["<PAD>"] = 0
word_index["<START"] = 1
word_index["<UNK>"] = 2
word_index["<UNUSED"] = 3

# %%
#Swap positions of values to keys, meaning instead of using numbers pointing to words, we have words point to numbers
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
#decode to readable english
def decode_review(text):
    return " ".join([reverse_word_index.get(i, "?") for i in text])

print(decode_review(train_data[0]))
# Out:
# <START this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert <UNK> is an amazing actor and now the same being director <UNK> father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for <UNK> and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also <UNK> to the two little boy's that played the <UNK> of norman and paul they were just brilliant children are often left out of the <UNK> list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %%
#check length of 2 reviews
print(len(train_data[0]), len(test_data[1]))
# Out:
# 218 260

# %%
#truncate data
train_data = keras.preprocessing.sequence.pad_sequences(train_data, value = word_index["<PAD>"],
                                                        padding = "post", maxlen= 256)
test_data = keras.preprocessing.sequence.pad_sequences(test_data, value = word_index["<PAD>"],
                                                       padding = "post", maxlen= 256)

# %%
#check length of 2 reviews again after truncating
print(len(test_data[0]), len(test_data[1]))
# Out:
# 256 256

# %%
#build model
model = keras.Sequential()
model.add(keras.layers.Embedding(10000, 16))
model.add(keras.layers.GlobalAveragePooling1D())
model.add(keras.layers.Dense(16, activation = "relu"))
model.add(keras.layers.Dense(1, activation = "sigmoid"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, None, 16)          160000
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,289
# Trainable params: 160,289
# Non-trainable params: 0
# _________________________________________________________________

# %%
#compile the model
model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])

# %%
#validate the model

#take up to 10000th reviews
x_val = train_data[:10000]
y_val = train_labels[:10000]

x_train = train_data[10000:]
y_train = train_labels[10000:]

#train the model by passing the dataset object to the fit method
#batch_size: how many reviews we will load
fitModel = model.fit(x_train, y_train, epochs=40, batch_size=512, validation_data=(x_val, y_val), verbose = 1)

#evaluate model
result = model.evaluate(test_data, test_labels)

print(result)
# Out:
# Epoch 1/40
# 30/30 [==============================] - 0s 12ms/step - loss: 0.6920 - accuracy: 0.5547 - val_loss: 0.6901 - val_accuracy: 0.6570
# Epoch 2/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.6868 - accuracy: 0.7211 - val_loss: 0.6824 - val_accuracy: 0.6571
# Epoch 3/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.6743 - accuracy: 0.7515 - val_loss: 0.6659 - val_accuracy: 0.7267
# Epoch 4/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.6509 - accuracy: 0.7719 - val_loss: 0.6392 - val_accuracy: 0.7626
# Epoch 5/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.6166 - accuracy: 0.7951 - val_loss: 0.6034 - val_accuracy: 0.7915
# Epoch 6/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.5736 - accuracy: 0.8170 - val_loss: 0.5615 - val_accuracy: 0.7978
# Epoch 7/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.5259 - accuracy: 0.8330 - val_loss: 0.5188 - val_accuracy: 0.8216
# Epoch 8/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.4790 - accuracy: 0.8481 - val_loss: 0.4769 - val_accuracy: 0.8334
# Epoch 9/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.4352 - accuracy: 0.8615 - val_loss: 0.4407 - val_accuracy: 0.8452
# Epoch 10/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3967 - accuracy: 0.8737 - val_loss: 0.4102 - val_accuracy: 0.8532
# Epoch 11/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.3645 - accuracy: 0.8811 - val_loss: 0.3855 - val_accuracy: 0.8581
# Epoch 12/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3373 - accuracy: 0.8895 - val_loss: 0.3659 - val_accuracy: 0.8635
# Epoch 13/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.3137 - accuracy: 0.8947 - val_loss: 0.3497 - val_accuracy: 0.8676
# Epoch 14/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2942 - accuracy: 0.9009 - val_loss: 0.3369 - val_accuracy: 0.8719
# Epoch 15/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.2770 - accuracy: 0.9053 - val_loss: 0.3274 - val_accuracy: 0.8731
# Epoch 16/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2618 - accuracy: 0.9105 - val_loss: 0.3174 - val_accuracy: 0.8768
# Epoch 17/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2476 - accuracy: 0.9159 - val_loss: 0.3102 - val_accuracy: 0.8789
# Epoch 18/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2353 - accuracy: 0.9199 - val_loss: 0.3044 - val_accuracy: 0.8796
# Epoch 19/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2245 - accuracy: 0.9225 - val_loss: 0.3000 - val_accuracy: 0.8810
# Epoch 20/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.2139 - accuracy: 0.9268 - val_loss: 0.2955 - val_accuracy: 0.8821
# Epoch 21/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.2040 - accuracy: 0.9307 - val_loss: 0.2928 - val_accuracy: 0.8828
# Epoch 22/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1956 - accuracy: 0.9341 - val_loss: 0.2899 - val_accuracy: 0.8845
# Epoch 23/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1868 - accuracy: 0.9382 - val_loss: 0.2877 - val_accuracy: 0.8843
# Epoch 24/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1788 - accuracy: 0.9416 - val_loss: 0.2863 - val_accuracy: 0.8840
# Epoch 25/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1720 - accuracy: 0.9445 - val_loss: 0.2869 - val_accuracy: 0.8840
# Epoch 26/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1646 - accuracy: 0.9475 - val_loss: 0.2849 - val_accuracy: 0.8853
# Epoch 27/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1582 - accuracy: 0.9505 - val_loss: 0.2843 - val_accuracy: 0.8859
# Epoch 28/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1519 - accuracy: 0.9530 - val_loss: 0.2845 - val_accuracy: 0.8855
# Epoch 29/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1457 - accuracy: 0.9559 - val_loss: 0.2852 - val_accuracy: 0.8853
# Epoch 30/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1401 - accuracy: 0.9581 - val_loss: 0.2857 - val_accuracy: 0.8860
# Epoch 31/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1347 - accuracy: 0.9605 - val_loss: 0.2868 - val_accuracy: 0.8860
# Epoch 32/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1296 - accuracy: 0.9622 - val_loss: 0.2884 - val_accuracy: 0.8857
# Epoch 33/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1250 - accuracy: 0.9641 - val_loss: 0.2900 - val_accuracy: 0.8858
# Epoch 34/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1202 - accuracy: 0.9663 - val_loss: 0.2918 - val_accuracy: 0.8855
# Epoch 35/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1156 - accuracy: 0.9679 - val_loss: 0.2946 - val_accuracy: 0.8848
# Epoch 36/40
# 30/30 [==============================] - 0s 7ms/step - loss: 0.1114 - accuracy: 0.9691 - val_loss: 0.2966 - val_accuracy: 0.8849
# Epoch 37/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.1074 - accuracy: 0.9707 - val_loss: 0.2983 - val_accuracy: 0.8840
# Epoch 38/40
# 30/30 [==============================] - 0s 9ms/step - loss: 0.1035 - accuracy: 0.9718 - val_loss: 0.3010 - val_accuracy: 0.8835
# Epoch 39/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0996 - accuracy: 0.9731 - val_loss: 0.3039 - val_accuracy: 0.8840
# Epoch 40/40
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0958 - accuracy: 0.9755 - val_loss: 0.3072 - val_accuracy: 0.8833
# 782/782 [==============================] - 0s 564us/step - loss: 0.3265 - accuracy: 0.8730
# [0.32653361558914185, 0.8729599714279175]

# %%
#test model
test_review = test_data[0]
predict = model.predict([test_review])
print("Review: " + decode_review(test_review))
print("Prediction: " + str(predict[0]))
print("Actual: " + str(test_labels[0]))
print(result)
# Out:
# Review: <START please give this one a miss br br <UNK> <UNK> and the rest of the cast rendered terrible performances the show is flat flat flat br br i don't know how michael madison could have allowed this one on his plate he almost seemed to know this wasn't going to work out and his performance was quite <UNK> so all you madison fans give this a miss <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Prediction: [2.0372317e-11]
# Actual: 0
# [0.32653361558914185, 0.8729599714279175]

# %%
#Create a plot of accuracy and loss over time
history_dict = fitModel.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history_dict["accuracy"]
val_acc = history_dict["accuracy"]
loss = history_dict['loss']
val_loss = history_dict['val_loss']

epochs = range(1, len(acc) + 1)

# "bo" is for blue dot
plt.plot(epochs, loss, 'bo', label = 'Training loss')
#b is for "solid blue line"
plt.plot(epochs, val_loss, 'b', label = 'Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.plot(epochs, acc, 'bo', label = 'Training acc')
plt.plot(epochs, val_acc, 'b', label = 'Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = 'lower right')

plt.show()
